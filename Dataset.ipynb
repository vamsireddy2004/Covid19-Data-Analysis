# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Data.csv')

# %%
data
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 86507     Zimbabwe      ZWE  2022-03-25           8691642.0
# 86508     Zimbabwe      ZWE  2022-03-26           8791728.0
# 86509     Zimbabwe      ZWE  2022-03-27           8845039.0
# 86510     Zimbabwe      ZWE  2022-03-28           8934360.0
# 86511     Zimbabwe      ZWE  2022-03-29           9039729.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
print(data.isnull().sum())
# Out:
# country                                    0
# iso_code                                   0
# date                                       0
# total_vaccinations                     42905
# people_vaccinated                      45218
# people_fully_vaccinated                47710
# daily_vaccinations_raw                 51150
# daily_vaccinations                       299
# total_vaccinations_per_hundred         42905
# people_vaccinated_per_hundred          45218
# people_fully_vaccinated_per_hundred    47710
# daily_vaccinations_per_million           299
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %%
data_cleaned = data.dropna()

# %%
data
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 86507     Zimbabwe      ZWE  2022-03-25           8691642.0
# 86508     Zimbabwe      ZWE  2022-03-26           8791728.0
# 86509     Zimbabwe      ZWE  2022-03-27           8845039.0
# 86510     Zimbabwe      ZWE  2022-03-28           8934360.0
# 86511     Zimbabwe      ZWE  2022-03-29           9039729.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
data_cleaned = data.dropna()
data.dropna(inplace=True)

# %%
data
# Out:
#            country iso_code        date  total_vaccinations  \
# 94     Afghanistan      AFG  2021-05-27            593313.0
# 101    Afghanistan      AFG  2021-06-03            630305.0
# 339    Afghanistan      AFG  2022-01-27           5081064.0
# 433        Albania      ALB  2021-02-18              3049.0
# 515        Albania      ALB  2021-05-11            622507.0
# ...            ...      ...         ...                 ...
# 86507     Zimbabwe      ZWE  2022-03-25           8691642.0
# 86508     Zimbabwe      ZWE  2022-03-26           8791728.0
# 86509     Zimbabwe      ZWE  2022-03-27           8845039.0
# 86510     Zimbabwe      ZWE  2022-03-28           8934360.0
# 86511     Zimbabwe      ZWE  2022-03-29           9039729.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 94              479574.0                 113739.0                  2859.0
# 101             481800.0                 148505.0                  4015.0
# ...

# %%
print(data.describe())
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        3.084700e+04       3.084700e+04             3.084700e+04
# mean         3.980375e+07       2.177533e+07             1.579596e+07
# std          1.451667e+08       8.053173e+07             5.898165e+07
# min          3.000000e+00       3.000000e+00             1.000000e+00
# 25%          1.153332e+06       7.339795e+05             3.704450e+05
# 50%          6.335305e+06       3.688092e+06             2.211035e+06
# 75%          2.520629e+07       1.440668e+07             9.121526e+06
# max          3.243599e+09       1.275541e+09             1.240777e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            3.084700e+04        3.084700e+04
# mean             2.021875e+05        1.975297e+05
# std              7.041931e+05        6.400504e+05
# min              0.000000e+00        0.000000e+00
# 25%              5.498000e+03        7.329500e+03
# ...

# %%
data.dtypes
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# dtype: object

# %%
print(data['country'].unique())
# Out:
# ['Afghanistan' 'Albania' 'Algeria' 'Andorra' 'Antigua and Barbuda'
#  'Argentina' 'Aruba' 'Australia' 'Azerbaijan' 'Bahamas' 'Bahrain'
#  'Bangladesh' 'Barbados' 'Belgium' 'Belize' 'Bhutan' 'Bolivia'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'Brunei' 'Bulgaria'
#  'Burundi' 'Cambodia' 'Cameroon' 'Canada' 'Cape Verde' 'Cayman Islands'
#  'Chile' 'China' 'Colombia' "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao'
#  'Cyprus' 'Czechia' 'Democratic Republic of Congo' 'Denmark' 'Dominica'
#  'Dominican Republic' 'Ecuador' 'Egypt' 'El Salvador' 'England'
#  'Equatorial Guinea' 'Estonia' 'Eswatini' 'Ethiopia' 'Faeroe Islands'
#  'Finland' 'France' 'French Polynesia' 'Gabon' 'Gambia' 'Georgia'
#  'Germany' 'Ghana' 'Gibraltar' 'Greece' 'Greenland' 'Grenada' 'Guatemala'
#  'Guernsey' 'Guinea' 'Guinea-Bissau' 'Guyana' 'Haiti' 'Honduras'
#  'Hong Kong' 'Hungary' 'Iceland' 'India' 'Indonesia' 'Iran' 'Ireland'
#  'Isle of Man' 'Israel' 'Italy' 'Jamaica' 'Japan' 'Jordan' 'Kazakhstan'
# ...

# %%
sns.histplot(data['daily_vaccinations'], bins=30)
plt.title('Distribution of Daily Vaccinations')
plt.show()

# %%
usa_data = data[data['country'] == 'United States']
print(usa_data.head())
# Out:
#              country iso_code        date  total_vaccinations  \
# 82361  United States      USA  2020-12-14             34867.0
# 82362  United States      USA  2020-12-15             84638.0
# 82363  United States      USA  2020-12-16            244549.0
# 82364  United States      USA  2020-12-17            517161.0
# 82365  United States      USA  2020-12-18            933551.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 82361            29543.0                   6017.0                  4579.0
# 82362            76984.0                   6281.0                 49771.0
# 82363           231496.0                   6757.0                159911.0
# 82364           496980.0                   7507.0                272612.0
# 82365           904656.0                   8718.0                416390.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 82361              4579.0                            0.01
# ...

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data
# Out:
#            country iso_code       date  total_vaccinations  people_vaccinated  \
# 94     Afghanistan      AFG 2021-05-27            593313.0           479574.0
# 101    Afghanistan      AFG 2021-06-03            630305.0           481800.0
# 339    Afghanistan      AFG 2022-01-27           5081064.0          4517380.0
# 433        Albania      ALB 2021-02-18              3049.0             2438.0
# 515        Albania      ALB 2021-05-11            622507.0           440921.0
# ...            ...      ...        ...                 ...                ...
# 86507     Zimbabwe      ZWE 2022-03-25           8691642.0          4814582.0
# 86508     Zimbabwe      ZWE 2022-03-26           8791728.0          4886242.0
# 86509     Zimbabwe      ZWE 2022-03-27           8845039.0          4918147.0
# 86510     Zimbabwe      ZWE 2022-03-28           8934360.0          4975433.0
# 86511     Zimbabwe      ZWE 2022-03-29           9039729.0          5053114.0
#
# ...

# %%
usa_data['total_vaccinations_rolling'] = usa_data['daily_vaccinations'].cumsum()
print(usa_data[['date', 'daily_vaccinations', 'total_vaccinations_rolling']])
# Out:
#              date  daily_vaccinations  total_vaccinations_rolling
# 82361  2020-12-14              4579.0                      4579.0
# 82362  2020-12-15             27175.0                     31754.0
# 82363  2020-12-16             71420.0                    103174.0
# 82364  2020-12-17            121718.0                    224892.0
# 82365  2020-12-18            180653.0                    405545.0
# ...           ...                 ...                         ...
# 82826  2022-03-24            156889.0                 559565883.0
# 82827  2022-03-25            149541.0                 559715424.0
# 82828  2022-03-26            143396.0                 559858820.0
# 82829  2022-03-27            137525.0                 559996345.0
# 82830  2022-03-28            115261.0                 560111606.0
#
# [470 rows x 3 columns]
# C:\Users\vamsi\AppData\Local\Temp\ipykernel_22128\2944669963.py:1: SettingWithCopyWarning:
# ...

# %%
country_vaccinations = data.groupby('country')['total_vaccinations'].max().reset_index()
print(country_vaccinations)
# Out:
#                  country  total_vaccinations
# 0            Afghanistan           5081064.0
# 1                Albania           2737859.0
# 2                Algeria          12293060.0
# 3                Andorra             15269.0
# 4    Antigua and Barbuda            125031.0
# ..                   ...                 ...
# 164           Uzbekistan          24300975.0
# 165              Vietnam         203144374.0
# 166                Wales           6927437.0
# 167               Zambia            592863.0
# 168             Zimbabwe           9039729.0
#
# [169 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(usa_data['date'], usa_data['daily_vaccinations'], label='Daily Vaccinations')
plt.title('Daily COVID-19 Vaccinations in the US')
plt.xlabel('Date')
plt.ylabel('Number of Vaccinations')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
top_countries = country_vaccinations.nlargest(10, 'total_vaccinations')

plt.figure(figsize=(12, 6))
sns.barplot(x='total_vaccinations', y='country', data=top_countries)
plt.title('Top 10 Countries by Total Vaccinations')
plt.show()

# %%
numeric_data = data.select_dtypes(include=['float64', 'int64'])
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
pip install -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
